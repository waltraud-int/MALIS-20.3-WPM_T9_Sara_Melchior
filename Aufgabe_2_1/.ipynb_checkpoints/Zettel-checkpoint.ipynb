# %%
tags = ["und", "ist", "Erding"]

with open('aus_der_heimat_test2.txt') as f:
    if 'und' in f.read():
        print("true")
# Out:
# true

# %%
string = ["und", "ist", "auch", "man"]

# opening a text file
file1 = open("aus_der_heimat_3_14.txt")

# read file content
readfile = file1.read()

res = any(ele in readfile for ele in string)

print('String contains list element : ' + str(res))
      
file1.close()
# Out:
# String contains list element : True

# %%
string = ["und", "ist", "auch", "man"]

# opening a text file
file1 = open("aus_der_heimat_3_14.txt")

# read file content
readfile = file1.read()

res = any(ele in readfile for ele in string)

print(string)
      
file1.close()
# Out:
# ['und', 'ist', 'auch', 'man']

# %%
string = ["und", "ist", "auch", "man"]
file = open("aus_der_heimat_3_14.txt")

with open('aus_der_heimat_3_14.txt') as f:
    if string[0] in f.read():
        print(string[0])
# Out:
# und

# %%
logPath = "aus_der_heimat_3_14.txt" 
file1 = open("only_tags.csv")

list_of_strings_to_search_for = file1.read()

with open(logPath) as file:
    for line in file:
        for s in list_of_strings_to_search_for:
            if s in line:
                #do something
                print(s)
# Out:
# n
# a
#
#
# r
# i
# t
# n
# s
# t
# i
# n
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# t
# n
# r
# i
# n
# g
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# r
# g
# r
# n
#
#
# 3
# r
# t
# s
# g
# r
# p
# p
# o
# r
# f
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# i
# t
# t
# i
# n
# g
#
#
# 5
# r
# t
# s
# g
# r
# p
# p
# r
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# i
# n
# s
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# o
# r
# s
# t
# r
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# r
# n
# a
# c
#
#
# r
# t
# s
# g
# r
# p
# p
# r
# a
# n
# r
# g
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# r
# n
# t
# g
# r
# n
# a
# c
#
#
# 1
# 1
# r
# t
# s
# g
# r
# p
# p
# o
# n
# p
# o
# i
# n
# g
#
#
# 1
# 2
# r
# t
# s
# g
# r
# p
# p
# o
# f
# i
# r
# c
# n
#
#
# 1
# 3
# r
# t
# s
# g
# r
# p
# p
# a
# n
# g
# n
# g
# i
# s
# i
# n
# g
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# a
# n
# g
# n
# p
# r
# i
# s
# i
# n
# g
#
#
# 1
# 5
# r
# t
# s
# g
# r
# p
# p
# n
# g
# o
# r
# f
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# o
# o
# s
# n
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# o
# o
# s
# i
# n
# n
# i
# n
# g
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# o
# t
# i
# n
# g
#
#
# 1
# r
# t
# s
# g
# r
# p
# p
# r
# i
# n
# g
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# i
# c
# n
# i
# r
# c
# n
#
#
# 2
# 1
# r
# t
# s
# g
# r
# p
# p
# t
# t
# n
# o
# f
# n
#
#
# 2
# 2
# r
# t
# s
# g
# r
# p
# p
# t
# i
# n
# i
# r
# c
# n
#
#
# 2
# 3
# r
# t
# s
# g
# r
# p
# p
# a
# f
# i
# r
# c
# n
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# a
# p
# r
# t
# s
# i
# r
# c
# n
#
#
# 2
# 5
# r
# t
# s
# g
# r
# p
# p
# a
# r
# t
# n
# r
# g
#
#
# 2
# a
# s
# t
# t
# t
# n
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# r
# a
# n
# r
# g
#
#
# 2
# i
# n
# i
# r
# n
# c
# i
# n
# g
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# r
# t
#
#
# 3
# i
# n
# n
# s
# a
# c
#
#
# n
# a
# m
# e
#
#
# 0
# r
# e
# i
# t
# e
# n
# s
# t
# e
# i
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# l
# t
# e
# n
# e
# r
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# e
# r
# g
# l
# e
# r
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# r
# f
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# i
# t
# t
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# i
# n
# s
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# r
# s
# t
# e
# r
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# n
# b
# a
# c
# h
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# a
# e
# n
# b
# e
# r
# g
#
#
# 0
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# n
# t
# e
# g
# e
# r
# n
# b
# a
# c
# h
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# h
# e
# n
# p
# o
# l
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# f
# i
# r
# c
# h
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# a
# n
# g
# e
# n
# g
# e
# i
# s
# l
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# a
# n
# g
# e
# n
# p
# r
# e
# i
# s
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# e
# n
# g
# o
# r
# f
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# o
# s
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# o
# s
# i
# n
# n
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# o
# t
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# b
# e
# r
# i
# n
# g
#
#
# 0
# r
# t
# s
# g
# r
# p
# p
# e
#
# R
# e
# i
# c
# h
# e
# n
# i
# r
# c
# h
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# t
# t
# e
# n
# h
# o
# f
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# t
# e
# i
# n
# i
# r
# c
# h
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# T
# a
# f
# i
# r
# c
# h
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# a
# l
# p
# e
# r
# t
# s
# i
# r
# c
# h
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# a
# r
# t
# e
# n
# b
# e
# r
# g
#
#
# e
# l
# l
# e
#
# a
# s
# t
# e
# t
# t
# e
# n
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# a
# n
# b
# e
# r
# g
#
#
# e
# m
# e
# i
# n
# e
#
# i
# e
# e
# r
# n
# e
# c
# h
# i
# n
# g
#
#
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# t
# h
#
#
# 0
# e
# m
# e
# i
# n
# e
#
# e
# b
# e
# n
# s
# b
# a
# c
# h
#
#
# n
# e
#
#
# 0
# r
# e
# t
# e
# n
# t
# e
# n
#
#
# r
# t
# g
# r
# u
# e
# l
# t
# e
# n
# e
# r
# d
# n
# g
#
#
# 2
# r
# t
# g
# r
# u
# e
# e
# r
# g
# l
# e
# r
# n
#
#
# r
# t
# g
# r
# u
# e
# o
# r
# e
# n
#
#
# r
# t
# g
# r
# u
# e
# t
# t
# n
# g
#
#
# 5
# r
# t
# g
# r
# u
# e
# r
# d
# n
# g
#
#
# r
# t
# g
# r
# u
# e
# n
# n
# g
#
#
# r
# t
# g
# r
# u
# e
# o
# r
# t
# e
# r
# n
#
#
# r
# t
# g
# r
# u
# e
# r
# n
# b
# c
#
#
# r
# t
# g
# r
# u
# e
# r
# u
# e
# n
# b
# e
# r
# g
#
#
# 0
# r
# t
# g
# r
# u
# e
# r
# p
# p
# e
#
# r
# t
# e
# n
# e
# r
# g
#
#
# 2
# e
# e
#
# s
# t
# e
# t
# t
# e
# n
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# n
# e
# r
# g
#
#
# 2
# e
# e
# i
# n
# d
# e
#
# i
# e
# d
# e
# r
# n
# e
# c
# i
# n
# g
#
#
# 2
# r
# t
# s
# g
# r
# p
# p
# e
#
# r
# t
#
#
# 0
# e
# e
# i
# n
# d
# e
#
# e
# e
# n
# s
# c
#
#
# n
# a
# m
# e
# 0
# B
# r
# e
# i
# t
# e
# n
# s
# t
# e
# i
# n
# 1
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# A
# l
# t
# e
# n
# e
# r
# d
# i
# n
# g
# 2
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# B
# e
# r
# g
# l
# e
# r
# n
# 3
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# D
# o
# r
# f
# e
# n
# 4
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# E
# i
# t
# t
# i
# n
# g
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# E
# r
# d
# i
# n
# g
# 6
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# F
# i
# n
# s
# i
# n
# g
# 7
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# F
# o
# r
# s
# t
# e
# r
# n
# 8
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# G
# r
# n
# b
# a
# c
# h
# 9
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# F
# r
# a
# u
# e
# n
# b
# e
# r
# g
# 1
# 0
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# G
# r
# n
# t
# e
# g
# e
# r
# n
# b
# a
# c
# h
# 1
# 1
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# H
# o
# h
# e
# n
# p
# o
# l
# d
# i
# n
# g
# 1
# 2
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# H
# o
# f
# k
# i
# r
# c
# h
# e
# n
# 1
# 3
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# L
# a
# n
# g
# e
# n
# g
# e
# i
# s
# l
# i
# n
# g
# 1
# 4
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# L
# a
# n
# g
# e
# n
# p
# r
# e
# i
# s
# i
# n
# g
# 1
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# L
# e
# n
# g
# d
# o
# r
# f
# 1
# 6
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# M
# o
# o
# s
# e
# n
# 1
# 7
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# M
# o
# o
# s
# i
# n
# n
# i
# n
# g
# 1
# 8
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# N
# o
# t
# z
# i
# n
# g
# 1
# 9
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# O
# b
# e
# r
# d
# i
# n
# g
# 2
# 0
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# R
# e
# i
# c
# h
# e
# n
# k
# i
# r
# c
# h
# e
# n
# 2
# 1
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# O
# t
# t
# e
# n
# h
# o
# f
# e
# n
# 2
# 2
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# S
# t
# e
# i
# n
# k
# i
# r
# c
# h
# e
# n
# 2
# 3
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# T
# a
# u
# f
# k
# i
# r
# c
# h
# e
# n
# 2
# 4
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# W
# a
# l
# p
# e
# r
# t
# s
# k
# i
# r
# c
# h
# e
# n
# 2
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# W
# a
# r
# t
# e
# n
# b
# e
# r
# g
# 2
# 6
# Z
# e
# l
# l
# e
#
# P
# a
# s
# t
# e
# t
# t
# e
# n
# 2
# 7
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# F
# r
# a
# u
# n
# b
# e
# r
# g
# 2
# 8
# G
# e
# m
# e
# i
# n
# d
# e
#
# N
# i
# e
# d
# e
# r
# n
# e
# u
# c
# h
# i
# n
# g
# 2
# 9
# O
# r
# t
# s
# g
# r
# u
# p
# p
# e
#
# W
# r
# t
# h
# 3
# 0
# G
# e
# m
# e
# i
# n
# d
# e
#
# G
# e
# b
# e
# n
# s
# b
# a
# c
# h

# %%
# opening a text file
file1 = open("aus_der_heimat_3_14.txt")
file2 = open("test.txt")

# read file content
readfile = file1.read()
readfile2 = file2.read()

# checking condition for string found or not
if (ele in readfile2 in readfile):
    print(ele)
else:
    print('Not Found')

# closing a file
file1.close()
file2.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-f78a7f099cd3> in <module>
#       8
#       9 # checking condition for string found or not
# ---> 10 if (ele in readfile2 in readfile):
#      11     print(ele)
#      12 else:
#
# NameError: name 'ele' is not defined

# %%
with open('aus_der_heimat_3_14.txt', 'r') as file1:
    with open('only_tags.csv', 'r') as file2:
        same = set(file1).intersection(file2)

same.discard('\n')

with open('output_file.txt', 'w') as file_out:
    for line in same:
        file_out.write(line)

# %%
# Open File in Read Mode
file_1 = open('aus_der_heimat_3_14.txt', 'r')
file_2 = open('only_tags.csv', 'r')
  
print("Comparing files ", " @ " + 'aus_der_heimat_3_14.txt', " # " + 'only_tags.csv', sep='\n')
  
file_1_line = file_1.readline()
file_2_line = file_2.readline()
  
  
print()
  
with open('aus_der_heimat_3_14.txt') as file1:
    with open('only_tags.csv') as file2:
        same = set(file1).intersection(file2)
  
print("Common Lines in Both Files")
  
print(line)


  
file_1.close()
file_2.close()

with open('output_file.txt', 'w') as file_out:
    for line in same:
        file_out.write(line)
# Out:
# Comparing files
#  @ aus_der_heimat_3_14.txt
#  # only_tags.csv
#
# Common Lines in Both Files
# + 30,Gemeinde Gebensbach

# %%
string = ["und", "ist", "auch", "man", "Ortsgruppe"]

# opening a text file
file1 = open("aus_der_heimat_3_14.txt")
file2 = open("only_tags.csv")

# read file content
readfile = file1.read()

# checking condition for string found or not
if file2(name) in readfile:
    print(name)
else:
    print(name , 'Not Found')

# closing a file
file1.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-747d217bae02> in <module>
#       9
#      10 # checking condition for string found or not
# ---> 11 if file2(name) in readfile:
#      12     print(name)
#      13 else:
#
# NameError: name 'name' is not defined

# %%
my_file = open("only_tags.csv", "r")

content = my_file.read()

print(content)


content_list = content.split(",")

my_file.close()

print(content_list)
# Out:
# ,name
# 0,Breitenstein
# 1,Ortsgruppe Altenerding
# 2,Ortsgruppe Berglern
# 3,Ortsgruppe Dorfen
# 4,Ortsgruppe Eitting
# 5,Ortsgruppe Erding
# 6,Ortsgruppe Finsing
# 7,Ortsgruppe Forstern
# 8,Ortsgruppe Grünbach
# 9,Ortsgruppe Frauenberg
# 10,Ortsgruppe Grüntegernbach
# 11,Ortsgruppe Hohenpolding
# 12,Ortsgruppe Hofkirchen
# 13,Ortsgruppe Langengeisling
# 14,Ortsgruppe Langenpreising
# 15,Ortsgruppe Lengdorf
# 16,Ortsgruppe Moosen
# 17,Ortsgruppe Moosinning
# 18,Ortsgruppe Notzing
# 19,Ortsgruppe Oberding
# 20,Ortsgruppe Reichenkirchen
# 21,Ortsgruppe Ottenhofen
# 22,Ortsgruppe Steinkirchen
# 23,Ortsgruppe Taufkirchen
# 24,Ortsgruppe Walpertskirchen
# 25,Ortsgruppe Wartenberg
# 26,Zelle Pastetten
# 27,Ortsgruppe Fraunberg
# 28,Gemeinde Niederneuching
# 29,Ortsgruppe Wörth
# 30,Gemeinde Gebensbach
#
# ['', 'name\n0', 'Breitenstein\n1', 'Ortsgruppe Altenerding\n2', 'Ortsgruppe Berglern\n3', 'Ortsgruppe Dorfen\n4', 'Ortsgruppe Eitting\n5', 'Ortsgruppe Erding\n6', 'Ortsgruppe Finsing\n7', 'Ortsgruppe Forstern\n8', 'Ortsgruppe Grünbach\n9', 'Ortsgruppe Frauenberg\n10', 'Ortsgruppe Grüntegernbach\n11', 'Ortsgruppe Hohenpolding\n12', 'Ortsgruppe Hofkirchen\n13', 'Ortsgruppe Langengeisling\n14', 'Ortsgruppe Langenpreising\n15', 'Ortsgruppe Lengdorf\n16', 'Ortsgruppe Moosen\n17', 'Ortsgruppe Moosinning\n18', 'Ortsgruppe Notzing\n19', 'Ortsgruppe Oberding\n20', 'Ortsgruppe Reichenkirchen\n21', 'Ortsgruppe Ottenhofen\n22', 'Ortsgruppe Steinkirchen\n23', 'Ortsgruppe Taufkirchen\n24', 'Ortsgruppe Walpertskirchen\n25', 'Ortsgruppe Wartenberg\n26', 'Zelle Pastetten\n27', 'Ortsgruppe Fraunberg\n28', 'Gemeinde Niederneuching\n29', 'Ortsgruppe Wörth\n30', 'Gemeinde Gebensbach\n']

# %%
#die Tags kann ich nun in einer Liste ansteuern
string = ['Ortsgruppe', 'Breitenstein\n1', 'Ortsgruppe Altenerding\n2', 'Ortsgruppe Berglern\n3', 'Ortsgruppe Dorfen\n4', 'Ortsgruppe Eitting\n5', 'Ortsgruppe Erding\n6', 'Ortsgruppe Finsing\n7', 'Ortsgruppe Forstern\n8', 'Ortsgruppe Grünbach\n9', 'Ortsgruppe Frauenberg\n10', 'Ortsgruppe Grüntegernbach\n11', 'Ortsgruppe Hohenpolding\n12', 'Ortsgruppe Hofkirchen\n13', 'Ortsgruppe Langengeisling\n14', 'Ortsgruppe Langenpreising\n15', 'Ortsgruppe Lengdorf\n16', 'Ortsgruppe Moosen\n17', 'Ortsgruppe Moosinning\n18', 'Ortsgruppe Notzing\n19', 'Ortsgruppe Oberding\n20', 'Ortsgruppe Reichenkirchen\n21', 'Ortsgruppe Ottenhofen\n22', 'Ortsgruppe Steinkirchen\n23', 'Ortsgruppe Taufkirchen\n24', 'Ortsgruppe Walpertskirchen\n25', 'Ortsgruppe Wartenberg\n26', 'Zelle Pastetten\n27', 'Ortsgruppe Fraunberg\n28', 'Gemeinde Niederneuching\n29', 'Ortsgruppe Wörth\n30', 'Gemeinde Gebensbach\n']

# ich öffne das Dokument, das ich durchsuchen will
file1 = open("aus_der_heimat_3_14.txt")

# lese es ein
readfile = file1.read()

# checke, ob ein bestimmter string enthalten ist. Ich habe lange herumprobiert - eigentlich möchte ich, dass alle Listenelemente
# durchsucht werden und ich nicht einen bestimmten über string[0] anwähle
if string[0] in readfile:
    print(string[0])
if string[0] in readfile:    
    outF = open("myOutFile.txt", "w")

# ich gebe den gesuchten string in einer Datei aus, auch hier hätte ich gern alle Ausdrücke aus der Liste ausgegeben, nicht nur string[0]
    outF.write(string[0])
    outF.write("\n")
    outF.close()
else:
    print(string[0], 'Not Found')

# closing a file
file1.close()
# Out:
# Ortsgruppe
